# %%
import numpy as np
import pandas as pd
df=pd.read_csv("placement.csv")
df.head()
print(df)
# Out:
#      cgpa   iq  placement
# 0    5.14   83          0
# 1    5.28   83          0
# 2    5.01   83          0
# 3    5.44   84          0
# 4    5.34   85          0
# ..    ...  ...        ...
# 195  8.72  119          1
# 196  8.97  119          1
# 197  8.68  119          1
# 198  9.06  120          1
# 199  9.01  121          1
#
# [200 rows x 3 columns]

# %% [markdown]
# #step1 preprocess- preprocess is like editing the dataset, removing unnecessary rows or column. but here the dataset is fine

# %%
# step-2 EDA- displaying the dataset

import matplotlib.pyplot as plt
plt.scatter(df["cgpa"],df['iq'])

# %%
plt.scatter(df["cgpa"],df['iq'],c=df["placement"])

# %% [markdown]
# the yellow line shows itne bando ka placement ho chuka hai

# %% [markdown]
# # step3 extract input and output columns

# %%
X=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
X
# Out:
#      cgpa   iq
# 0    5.14   83
# 1    5.28   83
# 2    5.01   83
# 3    5.44   84
# 4    5.34   85
# ..    ...  ...
# 195  8.72  119
# 196  8.97  119
# 197  8.68  119
# 198  9.06  120
# 199  9.01  121
#
# [200 rows x 2 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 195    1
# 196    1
# 197    1
# 198    1
# 199    1
# Name: placement, Length: 200, dtype: int64

# %% [markdown]
# # step4 Train_test_split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#      cgpa   iq
# 178  8.82  117
# 64   8.35   93
# 103  6.38  107
# 47   4.68   89
# 116  5.67  109
# ..    ...  ...
# 84   8.43   96
# 196  8.97  119
# 106  5.91  108
# 155  8.94  115
# 141  6.61  111
#
# [180 rows x 2 columns]

# %% [markdown]
# #  step5 Scale the value

# %%
from  sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 1.11010903,  1.22476391],
#        [ 0.8187816 , -0.76432635],
#        [-0.40231423,  0.3959763 ],
#        [-1.45605175, -1.0958414 ],
#        [-0.84240461,  0.56173382],
#        [-1.4064641 , -1.01296263],
#        [ 1.08531521,  1.22476391],
#        [-1.46225021, -1.34447768],
#        [ 1.14729977,  1.05900639],
#        [-0.83000769,  0.56173382],
#        [-0.60686328,  0.56173382],
#        [ 1.16589514,  1.05900639],
#        [ 1.09151366,  1.14188515],
#        [ 1.01713219, -0.59856883],
#        [ 1.13490286,  1.22476391],
#        [-0.97877064,  0.64461259],
#        [ 1.33325345,  1.39052143],
#        [ 1.16589514,  1.39052143],
#        [ 1.0729183 ,  1.22476391],
#        [ 0.53365263, -0.51569007],
#        [ 1.17209359,  1.30764267],
#        [ 0.75679704, -0.59856883],
#        [ 1.02333065,  1.39052143],
#        [ 1.09771212,  1.05900639],
#        [-1.31348726, -1.42735644],
#        [ 0.70101094, -0.43281131],
#        [ 1.10391058,  1.14188515],
# ...

# %%
X_test=sc.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.46546961, -0.84720511],
#        [-0.94777836,  0.72749135],
#        [-1.33828109, -1.17872016],
#        [-0.60686328,  0.72749135],
#        [-0.6316571 ,  0.3959763 ],
#        [-0.71843549,  0.56173382],
#        [ 0.78159087, -0.59856883],
#        [ 1.15349822,  1.30764267],
#        [-1.04695365, -1.42735644],
#        [ 0.68861403, -0.93008387],
#        [-1.31968572, -1.42735644],
#        [ 0.65762175, -0.68144759],
#        [-0.75562622,  0.81037011],
#        [-1.39406719, -1.26159892],
#        [ 1.19688742,  1.14188515],
#        [-1.25770116, -1.17872016],
#        [-1.45605175, -1.26159892],
#        [ 1.26507043,  1.22476391],
#        [-1.34447954, -1.17872016],
#        [ 0.94894918,  1.30764267]])

# %%
# training the data using logistic regression
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()

# %%
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(X_test)

# %%
y_test
# Out:
# 54     0
# 133    1
# 41     0
# 134    1
# 104    0
# 117    1
# 77     0
# 187    1
# 4      0
# 50     0
# 6      0
# 67     0
# 144    1
# 27     0
# 157    0
# 33     0
# 29     0
# 165    1
# 39     0
# 180    1
# Name: placement, dtype: int64

# %%
y_test
# Out:
# 54     0
# 133    1
# 41     0
# 134    1
# 104    0
# 117    1
# 77     0
# 187    1
# 4      0
# 50     0
# 6      0
# 67     0
# 144    1
# 27     0
# 157    0
# 33     0
# 29     0
# 165    1
# 39     0
# 180    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9
